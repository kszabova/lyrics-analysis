# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text2.concordance("sorrow")
# Out:
# Displaying 11 of 11 matches:
#  gave themselves up wholly to their sorrow , seeking increase of wretchedness
#  which is happiness itself . But in sorrow she must be equally carried away by
#  Colonel Brandon again repeated his sorrow at being the cause of disappointing
# enderest compassion of that violent sorrow which Marianne was in all probabili
# ll produced occasional effusions of sorrow as lively as ever . No letter from
# r occasion , to augment and fix her sorrow , by seeking silence , solitude and
# o assistance , their tenderness and sorrow must add to her distress , while he
#  ! how easy for those , who have no sorrow of their own to talk of exertion !
# magined liable to any impression of sorrow or of joy on his account -- she can
# m me the power of dissembling . Her sorrow , her disappointment , her deep reg
# y or friendship ; scarcely allowing sorrow to exist but with me , regretting o

# %%
text2.similar("sorrow")
# Out:
# it edward and her which one pleasure hope danger mind going spirits
# doubt friend memory poverty sense by in property

# %%
text2.common_contexts(["sorrow", "danger"])
# Out:
# no_of of_or

# %%
text3.similar("God")
# Out:
# he joseph pharaoh jacob they abraham she isaac sarah them him it i me
# abram laban thee cain esau judah

# %%
fig = text3.dispersion_plot(["God", "light", "day"])
fig

# %%
text4.generate()
# Out:
# Building ngram index...
# occur , and especially the truth that democratic government has innate
# capacity to govern its affairs aright through the Province ceded , by
# any timid forebodings of evil were not to overtake them while I
# possess the property of the peaks and the exercise of free and firm on
# the farm , in view that the best of my countrymen will ever find me
# ready to confer their benefits on countless generations yet to make
# its promise for all generations ." , remains essentially unchanged .
# cost of the Rocky Mountains . abuses of an ever - expanding American
# dream
# ...

# %%
text3.generate()
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %%
fdist = FreqDist(text3)

# %%
fdist.most_common(50)
# Out:
# [(',', 3681),
#  ('and', 2428),
#  ('the', 2411),
#  ('of', 1358),
#  ('.', 1315),
#  ('And', 1250),
#  ('his', 651),
#  ('he', 648),
#  ('to', 611),
#  (';', 605),
#  ('unto', 590),
#  ('in', 588),
#  ('that', 509),
#  ('I', 484),
#  ('said', 476),
#  ('him', 387),
#  ('a', 342),
#  ('my', 325),
#  ('was', 317),
#  ('for', 297),
#  ('it', 290),
#  ('with', 289),
#  ('me', 282),
#  ('thou', 272),
#  ("'", 268),
#  ('is', 267),
#  ('thy', 267),
#  ('s', 263),
#  ('thee', 257),
#  ('be', 254),
#  ('shall', 253),
#  ('they', 249),
#  ('all', 245),
#  (':', 238),
#  ('God', 231),
#  ('them', 230),
#  ('not', 224),
#  ('which', 198),
#  ('father', 198),
#  ('will', 195),
#  ('land', 184),
#  ('Jacob', 179),
#  ('came', 177),
#  ('her', 173),
#  ('LORD', 166),
#  ('were', 163),
#  ('she', 161),
#  ('from', 157),
#  ('Joseph', 157),
#  ('their', 153)]

# %%
fdist["earth"]
# Out:
# 111

# %%
fdist.hapaxes()
# Out:
# ['form',
#  'void',
#  'Day',
#  'Night',
#  'firmame',
#  'Heaven',
#  'appe',
#  'Earth',
#  'signs',
#  'seasons',
#  'lesser',
#  'nig',
#  'darkne',
#  'fly',
#  'whales',
#  'winged',
#  'seas',
#  'likene',
#  'subdue',
#  'finished',
#  'sanctified',
#  'plant',
#  'gr',
#  'mist',
#  'breathed',
#  'parted',
#  'Pison',
#  'bdellium',
#  'onyx',
#  'Gihon',
#  'Ethiopia',
#  'Hiddekel',
#  'Assyria',
#  'Euphrates',
#  'freely',
#  'eatest',
#  'sle',
#  'ribs',
#  'rib',
#  'Woman',
#  'Man',
#  'cleave',
#  'ashamed',
#  'subtil',
#  'gard',
#  'knowing',
#  'desired',
#  'sewed',
#  'fig',
#  'leaves',
#  'aprons',
#  'walking',
#  'cool',
#  'whereof',
#  'gavest',
#  'belly',
#  'enmity',
#  'conception',
#  'Thorns',
#  'thistles',
#  'sweat',
#  'tak',
#  'coats',
#  'clothed',
#  'Cherubims',
#  'flaming',
#  'tiller',
#  'firstlings',
#  'fallen',
#  'crieth',
#  'tillest',
#  'henceforth',
#  'punishment',
#  'driven',
#  'findeth',
#  'whosoever',
#  'slayeth',
# ...

# %%
[w for w in set(text2) if len(w) > 14]
# Out:
# ['incomprehensible',
#  'inquisitiveness',
#  'inconsiderately',
#  'dissatisfaction',
#  'congratulations',
#  'connoisseurship',
#  'disappointments',
#  'unobtrusiveness',
#  'disinterestedness',
#  'enfranchisement',
#  'disqualifications',
#  'instantaneously',
#  'proportionately',
#  'misapprehension',
#  'representations',
#  'companionableness',
#  'conscientiously',
#  'misconstruction',
#  'acknowledgments',
#  'disrespectfully']

# %%
fdist2 = FreqDist(text2)
sorted(w for w in set(text2) if len(w) > 7 and fdist[w] > 7)
# Out:
# ['according',
#  'answered',
#  'appeared',
#  'blessing',
#  'children',
#  'commanded',
#  'covenant',
#  'creature',
#  'daughter',
#  'daughters',
#  'departed',
#  'everlasting',
#  'exceedingly',
#  'families',
#  'gathered',
#  'generations',
#  'offering',
#  'possession',
#  'presence',
#  'returned',
#  'servants',
#  'themselves',
#  'therefore',
#  'together',
#  'youngest']

# %%
';'.join(text3.collocation_list())
# Out:
# 'said unto;pray thee;thou shalt;thou hast;thy seed;years old;spake unto;thou art;LORD God;every living;God hath;begat sons;seven years;shalt thou;little ones;living creature;creeping thing;savoury meat;thirty years;every beast'

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
shak = nltk.Text(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))

# %%
shak.concordance("king")
# Out:
# Displaying 25 of 55 matches:
# cena Secunda . Alarum within . Enter King Malcome , Donalbaine , Lenox , with
# ants , meeting a bleeding Captaine . King . What bloody man is that ? he can r
# ie : Haile braue friend ; Say to the King , the knowledge of the Broyle , As t
# ix ' d his Head vpon our Battlements King . O valiant Cousin , worthy Gentlema
#  to come , Discomfort swells : Marke King of Scotland , marke , No sooner Iust
# plyes of men , Began a fresh assault King . Dismay ' d not this our Captaines
# I am faint , My Gashes cry for helpe King . So well thy words become thee , as
#  things strange Rosse . God saue the King King . Whence cam ' st thou , worthy
# gs strange Rosse . God saue the King King . Whence cam ' st thou , worthy Than
# y Thane ? Rosse . From Fiffe , great King , Where the Norweyan Banners flowt t
# o conclude , The Victorie fell on vs King . Great happinesse Rosse . That now
# osse . That now Sweno , the Norwayes King , Craues composition : Nor would we
# ...

# %%
shak.collocation_list()
# Out:
# ['Enter Macbeth',
#  'Scena Secunda',
#  'three Witches',
#  'good Lord',
#  'thou art',
#  'Fire burne',
#  'Scena Prima',
#  'worthy Thane',
#  'ten thousand',
#  'weyward Sisters',
#  'mine owne',
#  'Cauldron bubble',
#  'haue done',
#  'Old man',
#  'Scena Quinta',
#  'thy face',
#  'Enter Malcolme',
#  'Scena Quarta',
#  'Lord Macb',
#  'Scena Tertia']

# %%
shak.generate()
# Out:
# Building ngram index...
# cold . , for ' t farre you ride ? Disasters , tugg ' d , Compell ' d
# any heart aliue To heare the men deny ' t . Be comforted . that do ' s
# blood vpon thy selfe , And hold thee to Heauen : oh come in , without
# the Pallace : alwayes thought , That by the verities on thee made good
# , May rush , and State , Children , and seize vs ? Lady . Time , and
# beare His hopes ' boue Wisedome , Grace , We will speake further , But
# "cold . , for ' t farre you ride ? Disasters , tugg ' d , Compell ' d\nany heart aliue To heare the men deny ' t . Be comforted . that do ' s\nblood vpon thy selfe , And hold thee to Heauen : oh come in , without\nthe Pallace : alwayes thought , That by the verities on thee made good\n, May rush , and State , Children , and seize vs ? Lady . Time , and\nbeare His hopes ' boue Wisedome , Grace , We will speake further , But"

# %%
ham = nltk.Text(nltk.corpus.gutenberg.words('shakespeare-hamlet.txt'))

# %%
ham.generate()
# Out:
# Building ngram index...
# erring Spirit , Doom ' d to be heard , and most Soueraigne Reason ,
# Like Quilles vpon the Iudgement : and now , was Yoricks Scull , the
# croaking Rauen doth bellow for Reuenge Lucian . , in a Violl , And let
# me be accurst , None wed the second , that thus hath cousend you at
# such time seeing me , I am very sorry good Horatio , I went round to
# worke , And thou shalt heare Ham . Ham . But let it be made , but to
# be last swallowed , when giuers proue
# "erring Spirit , Doom ' d to be heard , and most Soueraigne Reason ,\nLike Quilles vpon the Iudgement : and now , was Yoricks Scull , the\ncroaking Rauen doth bellow for Reuenge Lucian . , in a Violl , And let\nme be accurst , None wed the second , that thus hath cousend you at\nsuch time seeing me , I am very sorry good Horatio , I went round to\nworke , And thou shalt heare Ham . Ham . But let it be made , but to\nbe last swallowed , when giuers proue"

# %%
nltk.corpus.webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
pirates = nltk.Text(nltk.corpus.webtext.words('pirates.txt'))
freqPirates = FreqDist(pirates)
freqPirates.most_common(50)
# Out:
# [('the', 1028),
#  (':', 910),
#  (',', 846),
#  ('.', 790),
#  ('[', 643),
#  (']', 638),
#  ("'", 512),
#  ('a', 411),
#  ('!', 397),
#  ('to', 364),
#  ('of', 283),
#  ('Jack', 277),
#  ('s', 219),
#  ('?', 218),
#  ('I', 215),
#  ('you', 215),
#  ('and', 213),
#  ('is', 199),
#  ('JACK', 193),
#  ('SPARROW', 193),
#  ('in', 190),
#  ('on', 178),
#  ('*', 171),
#  ('it', 161),
#  ('-', 160),
#  ('his', 144),
#  ('WILL', 133),
#  ('TURNER', 133),
#  ('Will', 122),
#  ('...', 120),
#  ('with', 94),
#  ('ELIZABETH', 93),
#  ('SWANN', 93),
#  ('at', 91),
#  ('from', 89),
#  ('GIBBS', 86),
#  ('that', 82),
#  ('Elizabeth', 72),
#  ('t', 72),
#  ('up', 70),
#  ('as', 69),
#  ('for', 68),
#  ('You', 63),
#  ('are', 62),
#  ('off', 59),
#  ('back', 57),
#  ('your', 53),
#  ('we', 52),
#  ('ship', 52),
#  ('do', 51)]
